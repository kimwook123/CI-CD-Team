# %% [markdown]
# <a href="https://colab.research.google.com/github/kimwook123/CI-CD-Team/blob/main/0408%EA%B9%80%EC%B0%AC%EC%88%98%EA%B5%90%EC%88%98%EB%8B%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
os.listdir()

# %%
os.chdir('sample_data')

# %%
os.listdir()

# %%
os.getcwd()

# %%
try:
    print("try")
except:
    print("except")

# %%
try:
    num = int(input())
    assert num % 2 == 0, "Error message of assert"
except:
    print("Not an even number!")
else:
    reciprocal = 1 / num
    print(reciprocal)
